# %% [markdown]
# # Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b> Here is an example of a simple Jupyter Notebook </b>
#
# It's finally easier to understand while practicing

# %% [markdown]
# ### Below, there is a very simple mathematical expression with the further output. The code will calculate it automatically.

# %%
5*5
# Out:
# 25

# %% [markdown]
# This is an example how to create an ordered and unordered list :
#
# - Hobby
# + Goals
# * Sports
#     1. tennis
#     1. football
#     1. swimming
#
# 1. Hobby
# 3. Goals
#     - data science
#         * [GitHub](https://github.com/)
#         * programming
#     - sharing
# 4. Sports
#
# Go to [IBM](https://www.ibm.com/)
#
#
# ### Here is a sample of a table :
#
# | Monday | Tuesday | Wednesday | Thursday |  Friday  | Saturday | Sunday   |
# |:------:|:-------:|:---------:|:--------:|:--------:|:--------:|:--------:|
# | Sport  | GitHub  |    Work   |   Training  |   Work   | Sport    |  Hobby   |
# | Tennis |Programming| Training |  Work| Work| Soccer   |Travelling|
#
# ### Have a great day!!!
#
# ![Have a great day](https://live.staticflickr.com/871/41466163841_2a7a425483_b.jpg)
